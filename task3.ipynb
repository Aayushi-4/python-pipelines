# %%
import pandas as pd

# %%
df_customer=pd.read_csv(r"C:\Users\Aayushi\Downloads\us_customer_data 1.csv")
df_transactions=pd.read_csv(r"C:\Users\Aayushi\Downloads\transaction_data.csv")

# %%
merge_df=pd.merge(df_customer,df_transactions,on='customer_id',how='inner')

# %%
df_customer.head()
df_transactions.head()
# Out:
#    transaction_id  customer_id   amount     transaction_date product_category  \
# 0               1          565  2992.47  2025-03-10 01:20:54           Sports
# 1               2          323  2041.87  2025-01-02 15:24:19         Clothing
# 2               3          398   107.35  2025-02-16 03:49:01           Beauty
# 3               4           19      NaN  2025-04-30 15:26:23           Sports
# 4               5          547  3063.28  2025-06-14 04:28:53         Clothing
#
#   payment_method store_location
# 0     Debit Card       New York
# 1           Cash       New York
# 2     Debit Card         Online
# 3     Debit Card    Los Angeles
# 4         PayPal    Los Angeles

# %%
df_customer['phone']=df_customer['phone'].astype(str).str.replace(r'\D','',regex=True)

# %%
import random

# %%
# Function to generate random 10-digit phone number
def generate_phone():
    return ''.join([str(random.randint(0, 9)) for _ in range(10)])
 
# Replace empty phone numbers
df_customer['phone'] = df_customer['phone'].apply(lambda x: generate_phone() if pd.isna(x) or x == '' else x)

# %%
df_customer.isnull().sum()
# Out:
# customer_id           0
# name                  0
# email                50
# phone                 0
# address               0
# registration_date     0
# loyalty_status        0
# dtype: int64

# %%
df_customer.columns=df_customer.columns.str.strip()

# %%
df_customer['email']=df_customer['email'].fillna(df_customer['name'].str.replace(' ','').str.lower()+'@example.ccom')

# %%
transaction=df_transactions.dropna(subset=['amount'])

# %%
higher_value=merge_df[merge_df['amount']>merge_df['amount'].mean()]

# %%
higher_value
# Out:
#      customer_id               name                        email  \
# 0              1      Michelle Kidd           vayala@example.net
# 3              7       Louis Miller  patriciaelliott@example.org
# 6             10       Rachel White     whitemichael@example.org
# 7             10       Rachel White     whitemichael@example.org
# 9             12  Christine Delgado         yfarrell@example.net
# ..           ...                ...                          ...
# 990          991      Erica Fleming          erica85@example.net
# 991          991      Erica Fleming          erica85@example.net
# 992          992     Thomas Stevens    vargasmatthew@example.org
# 993          995     Deanna Johnson            ycook@example.org
# 994          995     Deanna Johnson            ycook@example.org
#
#             phone                                            address  \
# 0    619-723-4258                        USNS Santiago, FPO AE 80872
# ...

# %%
merge_df
# Out:
#      customer_id              name                        email         phone  \
# 0              1     Michelle Kidd           vayala@example.net  619-723-4258
# 1              4    Kimberly Price    jessicaknight@example.com  423-222-9779
# 2              5  Matthew Phillips        qwilliams@example.com  220-763-3522
# 3              7      Louis Miller  patriciaelliott@example.org  198-862-7105
# 4              7      Louis Miller  patriciaelliott@example.org  198-862-7105
# ..           ...               ...                          ...           ...
# 995          995    Deanna Johnson            ycook@example.org  576-320-4824
# 996          995    Deanna Johnson            ycook@example.org  576-320-4824
# 997          997      Jodi Simpson           eric24@example.org  483-625-2940
# 998          998     Crystal Brown         pshaffer@example.net  390-747-3088
# 999          998     Crystal Brown         pshaffer@example.net  390-747-3088
#
# ...
